# %%
# Simple BODMAS Calculator

while True:
    expr = input("Enter expression (or 'q' to quit): ")
    if expr.lower() == 'q':
        break
    try:
        result = eval(expr)   # Python automatically applies BODMAS
        print("Result:", result)
    except Exception as e:
        print("Error:", e)
